# %%
import pandas as pd
import plotly.express as px 
from plotly import graph_objs as go
from dash import Dash, dcc, html 
from dash.dependencies import Output, Input

# %% [markdown]
# This module we'll be looking at the New York City tree census. This data was provided by a volunteer driven census in 2015, and we'll be accessing it via the socrata API. The main site for the data is [here](https://data.cityofnewyork.us/Environment/2015-Street-Tree-Census-Tree-Data/uvpi-gqnh), and on the upper right hand side you'll be able to see the link to the API.
#
# The data is conveniently available in json format, so we should be able to just read it directly in to Pandas:

# %%
url = 'https://data.cityofnewyork.us/resource/nwxe-4ae8.json'
trees = pd.read_json(url)
trees.head(10)
# Out:
#    tree_id  block_id created_at  tree_dbh  stump_diam        curb_loc status  \
# 0   180683    348711 2015-08-27         3           0          OnCurb  Alive
# 1   200540    315986 2015-09-03        21           0          OnCurb  Alive
# 2   204026    218365 2015-09-05         3           0          OnCurb  Alive
# 3   204337    217969 2015-09-05        10           0          OnCurb  Alive
# 4   189565    223043 2015-08-30        21           0          OnCurb  Alive
# 5   190422    106099 2015-08-30        11           0          OnCurb  Alive
# 6   190426    106099 2015-08-30        11           0          OnCurb  Alive
# 7   208649    103940 2015-09-07         9           0          OnCurb  Alive
# 8   209610    407443 2015-09-08         6           0          OnCurb  Alive
# 9   192755    207508 2015-08-31        21           0  OffsetFromCurb  Alive
#
#   health                           spc_latin        spc_common  ...  boro_ct  \
# 0   Fair                         Acer rubrum         red maple  ...  4073900
# 1   Fair                   Quercus palustris           pin oak  ...  4097300
# 2   Good  Gleditsia triacanthos var. inermis       honeylocust  ...  3044900
# 3   Good  Gleditsia triacanthos var. inermis       honeylocust  ...  3044900
# 4   Good                     Tilia americana   American linden  ...  3016500
# 5   Good  Gleditsia triacanthos var. inermis       honeylocust  ...  1014500
# 6   Good  Gleditsia triacanthos var. inermis       honeylocust  ...  1014500
# 7   Good                     Tilia americana   American linden  ...  1012700
# 8   Good  Gleditsia triacanthos var. inermis       honeylocust  ...  5006400
# 9   Fair               Platanus x acerifolia  London planetree  ...  3037402
#
#       state   latitude  longitude          x_sp         y_sp council_district  \
# 0  New York  40.723092 -73.844215  1.027431e+06  202756.7687             29.0
# 1  New York  40.794111 -73.818679  1.034456e+06  228644.8374             19.0
# 2  New York  40.717581 -73.936608  1.001823e+06  200716.8913             34.0
# 3  New York  40.713537 -73.934456  1.002420e+06  199244.2531             34.0
# 4  New York  40.666778 -73.975979  9.909138e+05  182202.4260             39.0
# 5  New York  40.770046 -73.984950  9.884187e+05  219825.5227              3.0
# 6  New York  40.770210 -73.985338  9.883112e+05  219885.2785              3.0
# 7  New York  40.762724 -73.987297  9.877691e+05  217157.8561              3.0
# 8  New York  40.596579 -74.076255  9.630732e+05  156635.5542              NaN
# 9  New York  40.586357 -73.969744  9.926537e+05  152903.6306             47.0
#
#   census_tract        bin           bbl
# 0        739.0  4052307.0  4.022210e+09
# 1        973.0  4101931.0  4.044750e+09
# 2        449.0  3338310.0  3.028870e+09
# 3        449.0  3338342.0  3.029250e+09
# 4        165.0  3025654.0  3.010850e+09
# 5        145.0  1076229.0  1.011310e+09
# 6        145.0  1076229.0  1.011310e+09
# 7        133.0  1086093.0  1.010410e+09
# 8          NaN        NaN           NaN
# 9      37402.0  3320727.0  3.072350e+09
#
# [10 rows x 45 columns]

# %% [markdown]
# Looks good, but lets take a look at the shape of this data:

# %%
trees.shape
# Out:
# (1000, 45)

# %% [markdown]
# 1000 seems like too few trees for a city like New York, and a suspiciously round number. What's going on?
#
# Socrata places a 1000 row limit on their API. Raw data is meant to be "paged" through for applications, with the expectation that a UX wouldn't be able to handle a full dataset.
#
# As a simple example, if we had a mobile app with limited space that only displayed trees 5 at a time, we could view the first 5 trees in the dataset with the url below:

# %%
firstfive_url = 'https://data.cityofnewyork.us/resource/nwxe-4ae8.json?$limit=5&$offset=0'
firstfive_trees = pd.read_json(firstfive_url)
firstfive_trees
# Out:
#    tree_id  block_id created_at  tree_dbh  stump_diam curb_loc status health  \
# 0   180683    348711 2015-08-27         3           0   OnCurb  Alive   Fair
# 1   200540    315986 2015-09-03        21           0   OnCurb  Alive   Fair
# 2   204026    218365 2015-09-05         3           0   OnCurb  Alive   Good
# 3   204337    217969 2015-09-05        10           0   OnCurb  Alive   Good
# 4   189565    223043 2015-08-30        21           0   OnCurb  Alive   Good
#
#                             spc_latin       spc_common  ...  boro_ct  \
# 0                         Acer rubrum        red maple  ...  4073900
# 1                   Quercus palustris          pin oak  ...  4097300
# 2  Gleditsia triacanthos var. inermis      honeylocust  ...  3044900
# 3  Gleditsia triacanthos var. inermis      honeylocust  ...  3044900
# 4                     Tilia americana  American linden  ...  3016500
#
#       state   latitude  longitude         x_sp         y_sp council_district  \
# 0  New York  40.723092 -73.844215  1027431.148  202756.7687               29
# 1  New York  40.794111 -73.818679  1034455.701  228644.8374               19
# 2  New York  40.717581 -73.936608  1001822.831  200716.8913               34
# 3  New York  40.713537 -73.934456  1002420.358  199244.2531               34
# 4  New York  40.666778 -73.975979   990913.775  182202.4260               39
#
#   census_tract      bin         bbl
# 0          739  4052307  4022210001
# 1          973  4101931  4044750045
# 2          449  3338310  3028870001
# 3          449  3338342  3029250001
# 4          165  3025654  3010850052
#
# [5 rows x 45 columns]

# %% [markdown]
# If we wanted the next 5, we would use this url:

# %%
nextfive_url = 'https://data.cityofnewyork.us/resource/nwxe-4ae8.json?$limit=5&$offset=5'
nextfive_trees = pd.read_json(nextfive_url)
nextfive_trees
# Out:
#    tree_id  block_id created_at  tree_dbh  stump_diam        curb_loc status  \
# 0   190422    106099 2015-08-30        11           0          OnCurb  Alive
# 1   190426    106099 2015-08-30        11           0          OnCurb  Alive
# 2   208649    103940 2015-09-07         9           0          OnCurb  Alive
# 3   209610    407443 2015-09-08         6           0          OnCurb  Alive
# 4   192755    207508 2015-08-31        21           0  OffsetFromCurb  Alive
#
#   health                           spc_latin        spc_common  ...  boro_ct  \
# 0   Good  Gleditsia triacanthos var. inermis       honeylocust  ...  1014500
# 1   Good  Gleditsia triacanthos var. inermis       honeylocust  ...  1014500
# 2   Good                     Tilia americana   American linden  ...  1012700
# 3   Good  Gleditsia triacanthos var. inermis       honeylocust  ...  5006400
# 4   Fair               Platanus x acerifolia  London planetree  ...  3037402
#
#       state   latitude  longitude         x_sp         y_sp council_district  \
# 0  New York  40.770046 -73.984950  988418.6997  219825.5227              3.0
# 1  New York  40.770210 -73.985338  988311.1900  219885.2785              3.0
# 2  New York  40.762724 -73.987297  987769.1163  217157.8561              3.0
# 3  New York  40.596579 -74.076255  963073.1998  156635.5542              NaN
# 4  New York  40.586357 -73.969744  992653.7253  152903.6306             47.0
#
#   census_tract        bin           bbl
# 0        145.0  1076229.0  1.011310e+09
# 1        145.0  1076229.0  1.011310e+09
# 2        133.0  1086093.0  1.010410e+09
# 3          NaN        NaN           NaN
# 4      37402.0  3320727.0  3.072350e+09
#
# [5 rows x 45 columns]

# %% [markdown]
# You can read more about paging using the Socrata API [here](https://dev.socrata.com/docs/paging.html)
#
# In these docs, you'll also see more advanced functions (called `SoQL`) under the "filtering and query" section. These functions should be reminding you of SQL.
#
# Think about the shape you want your data to be in before querying it. Using `SoQL` is a good way to avoid the limits of the API. For example, using the below query I can easily obtain the count of each species of tree in the Bronx:

# %%
boro = 'Bronx'
soql_url = ('https://data.cityofnewyork.us/resource/nwxe-4ae8.json?' +\
        '$select=spc_common,count(tree_id)' +\
        '&$where=boroname=\'Bronx\'' +\
        '&$group=spc_common').replace(' ', '%20')
soql_trees = pd.read_json(soql_url)

soql_trees
# Out:
#      count_tree_id          spc_common
# 0             4619                 NaN
# 1               43        black walnut
# 2                9              spruce
# 3               62        tulip-poplar
# 4                7       trident maple
# ..             ...                 ...
# 128            195  crimson king maple
# 129            774    purple-leaf plum
# 130            363        sawtooth oak
# 131            505          willow oak
# 132            798         hedge maple
#
# [133 rows x 2 columns]

# %% [markdown]
# This behavior is very common with web APIs, and I think this is useful when thinking about building interactive data products. When in a Jupyter Notebook or RStudio, there's an expectation that (unless you're dealing with truly large datasets) the data you want can be brought in memory and manipulated.
#
# Dash and Shiny abstract away the need to distinguish between client side and server side to make web development more accessible to data scientists. This can lead to some unintentional design mistakes if you don't think about how costly your callback functions are (for example: nothing will stop you in dash from running a costly model triggered whenever a dropdown is called.)
#
# The goal of using the Socrata is to force you to think about where your data operations are happening, and not resort to pulling in the data and performing all operations in local memory.
#
# ----------
#
# **NOTE**: One tip in dealing with URLs: you may need to replace spaces with `'%20'`. I personally just write out the url and then follow the string with a replace:

# %%
'https://api-url.com/?query with spaces'.replace(' ', '%20')
# Out:
# 'https://api-url.com/?query%20with%20spaces'

# %%
pd.set_option("display.max_columns", None)
trees.head(10)
# Out:
#    tree_id  block_id created_at  tree_dbh  stump_diam        curb_loc status  \
# 0   180683    348711 2015-08-27         3           0          OnCurb  Alive
# 1   200540    315986 2015-09-03        21           0          OnCurb  Alive
# 2   204026    218365 2015-09-05         3           0          OnCurb  Alive
# 3   204337    217969 2015-09-05        10           0          OnCurb  Alive
# 4   189565    223043 2015-08-30        21           0          OnCurb  Alive
# 5   190422    106099 2015-08-30        11           0          OnCurb  Alive
# 6   190426    106099 2015-08-30        11           0          OnCurb  Alive
# 7   208649    103940 2015-09-07         9           0          OnCurb  Alive
# 8   209610    407443 2015-09-08         6           0          OnCurb  Alive
# 9   192755    207508 2015-08-31        21           0  OffsetFromCurb  Alive
#
#   health                           spc_latin        spc_common steward  \
# 0   Fair                         Acer rubrum         red maple    None
# 1   Fair                   Quercus palustris           pin oak    None
# 2   Good  Gleditsia triacanthos var. inermis       honeylocust    1or2
# 3   Good  Gleditsia triacanthos var. inermis       honeylocust    None
# 4   Good                     Tilia americana   American linden    None
# 5   Good  Gleditsia triacanthos var. inermis       honeylocust    1or2
# 6   Good  Gleditsia triacanthos var. inermis       honeylocust    1or2
# 7   Good                     Tilia americana   American linden    None
# 8   Good  Gleditsia triacanthos var. inermis       honeylocust    None
# 9   Fair               Platanus x acerifolia  London planetree    None
#
#     guards  sidewalk         user_type     problems root_stone root_grate  \
# 0     None  NoDamage  TreesCount Staff         None         No         No
# 1     None    Damage  TreesCount Staff       Stones        Yes         No
# 2     None    Damage         Volunteer         None         No         No
# 3     None    Damage         Volunteer       Stones        Yes         No
# 4     None    Damage         Volunteer       Stones        Yes         No
# 5  Helpful  NoDamage         Volunteer         None         No         No
# 6  Helpful  NoDamage         Volunteer         None         No         No
# 7     None  NoDamage         Volunteer  MetalGrates         No        Yes
# 8     None  NoDamage  TreesCount Staff         None         No         No
# 9     None  NoDamage  TreesCount Staff         None         No         No
#
#   root_other trunk_wire trnk_light trnk_other brch_light brch_shoe brch_other  \
# 0         No         No         No         No         No        No         No
# 1         No         No         No         No         No        No         No
# 2         No         No         No         No         No        No         No
# 3         No         No         No         No         No        No         No
# 4         No         No         No         No         No        No         No
# 5         No         No         No         No         No        No         No
# 6         No         No         No         No         No        No         No
# 7         No         No         No         No         No        No         No
# 8         No         No         No         No         No        No         No
# 9         No         No         No         No         No        No         No
#
#               address  zipcode       zip_city  cb_num  borocode  \
# 0   108-005 70 AVENUE    11375   Forest Hills     406         4
# 1    147-074 7 AVENUE    11357     Whitestone     407         4
# 2   390 MORGAN AVENUE    11211       Brooklyn     301         3
# 3   1027 GRAND STREET    11211       Brooklyn     301         3
# 4        603 6 STREET    11215       Brooklyn     306         3
# 5   8 COLUMBUS AVENUE    10023       New York     107         1
# 6  120 WEST 60 STREET    10023       New York     107         1
# 7  311 WEST 50 STREET    10019       New York     104         1
# 8    65 JEROME AVENUE    10305  Staten Island     502         5
# 9        638 AVENUE Z    11223       Brooklyn     313         3
#
#         boroname  cncldist  st_assem  st_senate   nta  \
# 0         Queens        29        28         16  QN17
# 1         Queens        19        27         11  QN49
# 2       Brooklyn        34        50         18  BK90
# 3       Brooklyn        34        53         18  BK90
# 4       Brooklyn        39        44         21  BK37
# 5      Manhattan         3        67         27  MN14
# 6      Manhattan         3        67         27  MN14
# 7      Manhattan         3        75         27  MN15
# 8  Staten Island        50        64         23  SI14
# 9       Brooklyn        47        45         23  BK26
#
#                           nta_name  boro_ct     state   latitude  longitude  \
# 0                     Forest Hills  4073900  New York  40.723092 -73.844215
# 1                       Whitestone  4097300  New York  40.794111 -73.818679
# 2                East Williamsburg  3044900  New York  40.717581 -73.936608
# 3                East Williamsburg  3044900  New York  40.713537 -73.934456
# 4               Park Slope-Gowanus  3016500  New York  40.666778 -73.975979
# 5                   Lincoln Square  1014500  New York  40.770046 -73.984950
# 6                   Lincoln Square  1014500  New York  40.770210 -73.985338
# 7                          Clinton  1012700  New York  40.762724 -73.987297
# 8  Grasmere-Arrochar-Ft. Wadsworth  5006400  New York  40.596579 -74.076255
# 9                        Gravesend  3037402  New York  40.586357 -73.969744
#
#            x_sp         y_sp  council_district  census_tract        bin  \
# 0  1.027431e+06  202756.7687              29.0         739.0  4052307.0
# 1  1.034456e+06  228644.8374              19.0         973.0  4101931.0
# 2  1.001823e+06  200716.8913              34.0         449.0  3338310.0
# 3  1.002420e+06  199244.2531              34.0         449.0  3338342.0
# 4  9.909138e+05  182202.4260              39.0         165.0  3025654.0
# 5  9.884187e+05  219825.5227               3.0         145.0  1076229.0
# 6  9.883112e+05  219885.2785               3.0         145.0  1076229.0
# 7  9.877691e+05  217157.8561               3.0         133.0  1086093.0
# 8  9.630732e+05  156635.5542               NaN           NaN        NaN
# 9  9.926537e+05  152903.6306              47.0       37402.0  3320727.0
#
#             bbl
# 0  4.022210e+09
# 1  4.044750e+09
# 2  3.028870e+09
# 3  3.029250e+09
# 4  3.010850e+09
# 5  1.011310e+09
# 6  1.011310e+09
# 7  1.010410e+09
# 8           NaN
# 9  3.072350e+09

# %% [markdown]
# # Assignment 4

# %%
external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

# Setting up the app
app = dash.Dash(__name__, external_stylesheets=external_stylesheets)

# setting up the server
server = app.server

#Getting the data where I want to focus on the spc_common,boroname,health,steward,count
url = ('https://data.cityofnewyork.us/resource/nwxe-4ae8.json?' +
       '$select=spc_common,boroname,health,steward,count(tree_id)' +
       '&$group=spc_common,boroname,health,steward').replace(' ', '%20')

# %%
def paging(data, test):
    return pd.concat([data, test])

# %%
# Read the data
df = pd.read_json(url)
df
# Out:
#          spc_common   boroname health  steward  count_tree_id
# 0    American beech      Bronx   Fair     1or2              3
# 1    American beech      Bronx   Fair     3or4              1
# 2    American beech      Bronx   Fair     None              3
# 3    American beech      Bronx   Good     1or2              2
# 4    American beech      Bronx   Good     3or4              1
# ..              ...        ...    ...      ...            ...
# 995     Chinese elm  Manhattan   Good     None            336
# 996     Chinese elm  Manhattan   Poor     1or2             14
# 997     Chinese elm  Manhattan   Poor     3or4              6
# 998     Chinese elm  Manhattan   Poor  4orMore              1
# 999     Chinese elm  Manhattan   Poor     None             21
#
# [1000 rows x 5 columns]

# %% [markdown]
# Clean the data

# %%
# Clean the data
df_all = pd.DataFrame()

incre = 0
while True:

    if df.empty:
        break
    else:

        df_all = paging(df_all, df)
        incre += 1
        df = pd.read_json(url + '&$offset=' + str(incre) + '000')

df_all.dropna()
# Out:
#          spc_common       boroname health steward  count_tree_id
# 0    American beech          Bronx   Fair    1or2              3
# 1    American beech          Bronx   Fair    3or4              1
# 2    American beech          Bronx   Fair    None              3
# 3    American beech          Bronx   Good    1or2              2
# 4    American beech          Bronx   Good    3or4              1
# ..              ...            ...    ...     ...            ...
# 551      willow oak  Staten Island   Good    1or2             29
# 552      willow oak  Staten Island   Good    3or4              4
# 553      willow oak  Staten Island   Good    None            177
# 554      willow oak  Staten Island   Poor    1or2              2
# 555      willow oak  Staten Island   Poor    None              9
#
# [4554 rows x 5 columns]

# %%
# the app layout
app.layout = html.Div([
    html.Div([
    html.H1(children='Tree NYC'),
    html.H4(children='Dropdown by Borough and Species')]),
    html.Div([
    dcc.Dropdown(
        id='borough',
        options=[
            {'label': i, 'value': i}
            for i in df_all['boroname'].dropna().unique()
        ],
        value='Manhattan',
        multi=False,
        className="dcc_control"
        
    ),
    dcc.Dropdown(
        id='species',
        options=[
            {'label': i, 'value': i}
            for i in df_all['spc_common'].dropna().unique()
        ],
        value='red maple',
        multi=False,
        className="dcc_control"
        
    )]

    ),
    html.Div([
    dcc.Graph(id='graph_1')],
    className="mini_container"),
    html.Div([
    html.H4(children='Tree Health by Steward '),
    dcc.Graph(id='graph_2')

    ],className="mini_container" )
])

# %%
# First Graph
@app.callback(
    dash.dependencies.Output('graph_1', 'figure'),
    [dash.dependencies.Input('borough', 'value'),
     dash.dependencies.Input('species', 'value')])
def Graph_1(borough_value, species_value):
    one_case_filter = df_all[(df_all['boroname'] == borough_value) &
                             (df_all['spc_common'] == species_value)]
    health_count = one_case_filter.groupby('health').sum()['count_tree_id']

    return {"data": [go.Bar(x=health_count.index, y=health_count)],
            "layout": go.Layout(title=" Tree Health Count")}

# %%
# Second Graph
@app.callback(
    dash.dependencies.Output('graph_2', 'figure'),
    [dash.dependencies.Input('borough', 'value'),
     dash.dependencies.Input('species', 'value')])

def Graph_2(borough_value, species_value):
    one_case_filter = df_all[(df_all['boroname'] == borough_value) &
                             (df_all['spc_common'] == species_value)]
    health_count = one_case_filter.groupby('health').sum()['count_tree_id']
    steward_count = one_case_filter.groupby('steward').sum()['count_tree_id']

    tree_steward = pd.merge(one_case_filter,
                            pd.DataFrame(steward_count),
                            on='steward')

    tree_steward['percent'] = round(
        tree_steward['count_tree_id_x']/tree_steward['count_tree_id_y'] * 100, 2)

    df = px.data.tips()
    fig = px.bar(tree_steward, x="steward",
                 y="percent", color='health', barmode='group')

# %%
# Run the dash
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-20-af51fc25210f> in <module>
#       1 # Run the dash
#       2 if __name__ == '__main__':
# ----> 3     app.run_server(debug=True)
#
# /opt/anaconda3/lib/python3.8/site-packages/dash/dash.py in run_server(self, host, port, proxy, debug, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_prune_errors, **flask_run_options)
#    2031                     extra_files.append(path)
#    2032
# -> 2033         self.server.run(host=host, port=port, debug=debug, **flask_run_options)
#
# /opt/anaconda3/lib/python3.8/site-packages/flask/app.py in run(self, host, port, debug, load_dotenv, **options)
#     988
#     989         try:
# --> 990             run_simple(host, port, self, **options)
#     991         finally:
#     992             # reset the first request information if the development server
#
# /opt/anaconda3/lib/python3.8/site-packages/werkzeug/serving.py in run_simple(hostname, port, application, use_reloader, use_debugger, use_evalex, extra_files, reloader_interval, reloader_type, threaded, processes, request_handler, static_files, passthrough_errors, ssl_context)
#    1028             s = socket.socket(address_family, socket.SOCK_STREAM)
#    1029             s.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
# -> 1030             s.bind(server_address)
#    1031             if hasattr(s, "set_inheritable"):
#    1032                 s.set_inheritable(True)
#
# OSError: [Errno 48] Address already in use

# %% [markdown]
# ### For whatever reason I had a hard time running this app, it keeps loading forever.
